# %% [markdown]
# Data frames are most commonly used pandas object.Its like a spreadsheet or a SQL talbe

# %%
import pandas as pa

# %%
#dataf= pa.read_csv('pokemon_data.csv')
dataf= pa.read_excel('pokemon_data.xlsx')

# %%
print (dataf.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
dataf= pa.read_csv('pokemon_data.txt',delimiter='\t')

# %%
print(dataf.head(5))
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary
# 0       65     45           1      False
# 1       80     60           1      False
# 2      100     80           1      False
# 3      120     80           1      False
# 4       50     65           1      False

# %%
#read Headers
#print(dataf.columns)
#read secific columns
#print(dataf[['Name','Speed']])
#read rows
#print(dataf.iloc[1])
#print(dataf.iloc[0:4]) # print 0 to 4
#read to specific cell with row num and col num
print(dataf.iloc[1,3])
# Out:
# Poison

# %%
for index,row1 in dataf.iterrows():
    print(index,row1['Speed'])
# Out:
# 0 45
# 1 60
# 2 80
# 3 80
# 4 65
# 5 80
# 6 100
# 7 100
# 8 100
# 9 43
# 10 58
# 11 78
# 12 78
# 13 45
# 14 30
# 15 70
# 16 50
# 17 35
# 18 75
# 19 145
# 20 56
# 21 71
# 22 101
# 23 121
# 24 72
# 25 97
# 26 70
# 27 100
# 28 55
# 29 80
# 30 90
# 31 110
# 32 40
# 33 65
# 34 41
# 35 56
# 36 76
# 37 50
# 38 65
# 39 85
# 40 35
# 41 60
# 42 65
# 43 100
# 44 20
# 45 45
# 46 55
# 47 90
# 48 30
# 49 40
# 50 50
# 51 25
# 52 30
# 53 45
# 54 90
# 55 95
# 56 120
# 57 90
# 58 115
# 59 55
# 60 85
# 61 70
# 62 95
# 63 60
# 64 95
# 65 90
# 66 90
# 67 70
# 68 90
# 69 105
# 70 120
# 71 150
# 72 35
# 73 45
# 74 55
# 75 40
# 76 55
# 77 70
# 78 70
# 79 100
# 80 20
# 81 35
# 82 45
# 83 90
# 84 105
# 85 15
# 86 30
# 87 30
# 88 45
# 89 70
# 90 60
# 91 75
# 92 100
# 93 45
# 94 70
# 95 25
# 96 50
# 97 40
# 98 70
# 99 80
# 100 95
# 101 110
# 102 130
# 103 70
# 104 42
# 105 67
# 106 50
# 107 75
# 108 100
# 109 140
# 110 40
# 111 55
# 112 35
# 113 45
# 114 87
# 115 76
# 116 30
# 117 35
# 118 60
# 119 25
# 120 40
# ...

# %%
dataf.loc[dataf['Type 1']=="Fire"]
# Out:
#        #                       Name Type 1    Type 2   HP  Attack  Defense  \
# 4      4                 Charmander   Fire       NaN   39      52       43
# 5      5                 Charmeleon   Fire       NaN   58      64       58
# 6      6                  Charizard   Fire    Flying   78      84       78
# 7      6  CharizardMega Charizard X   Fire    Dragon   78     130      111
# 8      6  CharizardMega Charizard Y   Fire    Flying   78     104       78
# 42    37                     Vulpix   Fire       NaN   38      41       40
# 43    38                  Ninetales   Fire       NaN   73      76       75
# 63    58                  Growlithe   Fire       NaN   55      70       45
# 64    59                   Arcanine   Fire       NaN   90     110       80
# 83    77                     Ponyta   Fire       NaN   50      85       55
# 84    78                   Rapidash   Fire       NaN   65     100       70
# ...

# %% [markdown]
# #Sorting/Describing Data - Tells  the means std etc

# %%
dataf.describe()
# Out:
#                 #          HP      Attack     Defense     Sp. Atk     Sp. Def  \
# count  800.000000  800.000000  800.000000  800.000000  800.000000  800.000000
# mean   362.813750   69.258750   79.001250   73.842500   72.820000   71.902500
# std    208.343798   25.534669   32.457366   31.183501   32.722294   27.828916
# min      1.000000    1.000000    5.000000    5.000000   10.000000   20.000000
# 25%    184.750000   50.000000   55.000000   50.000000   49.750000   50.000000
# 50%    364.500000   65.000000   75.000000   70.000000   65.000000   70.000000
# 75%    539.250000   80.000000  100.000000   90.000000   95.000000   90.000000
# max    721.000000  255.000000  190.000000  230.000000  194.000000  230.000000
#
#             Speed  Generation
# count  800.000000   800.00000
# mean    68.277500     3.32375
# std     29.060474     1.66129
# min      5.000000     1.00000
# 25%     45.000000     2.00000
# 50%     65.000000     3.00000
# 75%     90.000000     5.00000
# ...

# %% [markdown]
# #Sorting

# %%
dataf.sort_values(['Type 1','HP'],ascending=True)
# Out:
#        #       Name Type 1  Type 2   HP  Attack  Defense  Sp. Atk  Sp. Def  \
# 316  292   Shedinja    Bug   Ghost    1      90       45       30       30
# 230  213    Shuckle    Bug    Rock   20      10      230       10      230
# 462  415     Combee    Bug  Flying   30      30       42       30       42
# 603  543   Venipede    Bug  Poison   30      45       59       30       39
# 314  290    Nincada    Bug  Ground   31      45       90       30       30
# ..   ...        ...    ...     ...  ...     ...      ...      ...      ...
# 142  131     Lapras  Water     Ice  130      85       80       85       95
# 145  134   Vaporeon  Water     NaN  130      65       60      110       95
# 350  320    Wailmer  Water     NaN  130      70       35       70       35
# 655  594  Alomomola  Water     NaN  165      75       80       40       45
# 351  321    Wailord  Water     NaN  170      90       45       90       45
#
#      Speed  Generation  Legendary
# ...

# %% [markdown]
# #adding to a category

# %%
dataf['Total'] = dataf['HP']+dataf['Attack']+dataf['Defense']

# %%
dataf.head()# You can see the Total Column
# Out:
#    #                   Name Type 1  Type 2  HP  Attack  Defense  Sp. Atk  \
# 0  1              Bulbasaur  Grass  Poison  45      49       49       65
# 1  2                Ivysaur  Grass  Poison  60      62       63       80
# 2  3               Venusaur  Grass  Poison  80      82       83      100
# 3  3  VenusaurMega Venusaur  Grass  Poison  80     100      123      122
# 4  4             Charmander   Fire     NaN  39      52       43       60
#
#    Sp. Def  Speed  Generation  Legendary  Total
# 0       65     45           1      False    143
# 1       80     60           1      False    185
# 2      100     80           1      False    245
# 3      120     80           1      False    303
# 4       50     65           1      False    134

# %%
#Drop a column
dataf.drop(columns='Total')
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary
# 0         65       65     45           1      False
# ...

# %%
dataf
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total
# 0         65       65     45           1      False    143
# ...

# %%
dataf['Totalnew']=dataf.iloc[:,4:9].sum(axis=1)
#sum function
#when axis is 1 it adds horizontally
#when axis is 0 it adds vertically

# %%
print(dataf['Total'])
# Out:
# 0      143
# 1      185
# 2      245
# 3      303
# 4      134
#       ...
# 795    300
# 796    320
# 797    250
# 798    300
# 799    310
# Name: Total, Length: 800, dtype: int64

# %%
dataf.drop(columns='Total')
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Totalnew
# 0         65       65     45           1      False       273
# ...

# %%
dataf
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Total  Totalnew
# ...

# %%
del dataf['Total']

# %%
dataf
# Out:
#        #                   Name   Type 1  Type 2  HP  Attack  Defense  \
# 0      1              Bulbasaur    Grass  Poison  45      49       49
# 1      2                Ivysaur    Grass  Poison  60      62       63
# 2      3               Venusaur    Grass  Poison  80      82       83
# 3      3  VenusaurMega Venusaur    Grass  Poison  80     100      123
# 4      4             Charmander     Fire     NaN  39      52       43
# ..   ...                    ...      ...     ...  ..     ...      ...
# 795  719                Diancie     Rock   Fairy  50     100      150
# 796  719    DiancieMega Diancie     Rock   Fairy  50     160      110
# 797  720    HoopaHoopa Confined  Psychic   Ghost  80     110       60
# 798  720     HoopaHoopa Unbound  Psychic    Dark  80     160       60
# 799  721              Volcanion     Fire   Water  80     110      120
#
#      Sp. Atk  Sp. Def  Speed  Generation  Legendary  Totalnew
# 0         65       65     45           1      False       273
# ...

# %% [markdown]
# #moving the colums to the right and left in the dataframe

# %%
cols = list(dataf.columns.values)
dataf = dataf[cols[0:4]+[cols[-1] ]+ cols[4:12]]

# %%
dataf
# Out:
#        #                   Name   Type 1  Type 2  Totalnew  HP  Attack  \
# 0      1              Bulbasaur    Grass  Poison       273  45      49
# 1      2                Ivysaur    Grass  Poison       345  60      62
# 2      3               Venusaur    Grass  Poison       445  80      82
# 3      3  VenusaurMega Venusaur    Grass  Poison       545  80     100
# 4      4             Charmander     Fire     NaN       244  39      52
# ..   ...                    ...      ...     ...       ...  ..     ...
# 795  719                Diancie     Rock   Fairy       550  50     100
# 796  719    DiancieMega Diancie     Rock   Fairy       590  50     160
# 797  720    HoopaHoopa Confined  Psychic   Ghost       530  80     110
# 798  720     HoopaHoopa Unbound  Psychic    Dark       600  80     160
# 799  721              Volcanion     Fire   Water       530  80     110
#
#      Defense  Sp. Atk  Sp. Def  Speed  Generation  Legendary
# ...

# %% [markdown]
# Saving our CSv

# %%
dataf.to_csv('modified.csv')
